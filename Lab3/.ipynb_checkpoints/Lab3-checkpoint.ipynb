# %% [markdown]
# # Lab 3: Modelo condicional para imagens
#
# No último laboratório, vamos estudar a geração condicional de imagens, usando o dataset MNIST. Tal dataset contém, 32 x 32 = 1024 dimensões! Desse modo, tal conjunto de dados exigirá:
#
#     1. O uso da classificação livre guiada (classifier-free - CFG, parte 2.1);
#
#     2. Para a parametrização do vetor de aprendizagem, uma simples arquitetura MLP não será suficiente, exigindo assim, o uso de uma arquitetura consideravelmente mais robusto, que neste caso, será a U-Net (parte 2.2);

# %%
# Imports necessários
from abc import ABC, abstractmethod
from typing import Optional, List, Type, Dict
import math

import numpy as np
from matplotlib import pyplot as plt
from matplotlib.axes._axes import Axes
import torch
import torch.nn as nn
import torch.distributions as D
from tqdm import tqdm
import seaborn as sns
from sklearn.datasets import make_moons, make_circles
from torchvision import datasets, transforms
from torchvision.utils import make_grid

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 9
#       7 from matplotlib import pyplot as plt
#       8 from matplotlib.axes._axes import Axes
# ----> 9 import torchvision
#      10 import torch
#      11 import torch.nn as nn
#
# File ~\anaconda3\envs\IA_Gen_env\Lib\site-packages\torchvision\__init__.py:8
#       5 # Don't re-order these, we need to load the _C extension (done when importing
#       6 # .extension) before entering _meta_registrations.
#       7 from . import extension  # usort:skip  # noqa: F401
# ----> 8 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      10 try:
#      11     from .version import __version__  # noqa: F401
#
# File ~\anaconda3\envs\IA_Gen_env\Lib\site-packages\torchvision\_meta_registrations.py:163
#     153     torch._check(
#     154         grad.dtype == rois.dtype,
#     155         lambda: (
#    (...)    158         ),
#     159     )
#     160     return grad.new_empty((batch_size, channels, height, width))
# --> 163 @torch.library.register_fake("torchvision::nms")
#     164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#     166     torch._check(dets.size(1) == 4, lambda: f"boxes should have 4 elements in dimension 1, got {dets.size(1)}")
#
# File ~\anaconda3\envs\IA_Gen_env\Lib\site-packages\torch\library.py:1023, in register(func)
#     962 def register_fake(
#     963     op: _op_identifier,
#     964     func: Callable | None = None,
#    (...)    969     allow_override: bool = False,
#     970 ):
#     971     r"""Register a FakeTensor implementation ("fake impl") for this operator.
#     972
#     973     Also sometimes known as a "meta kernel", "abstract impl".
#     974
#     975     An "FakeTensor implementation" specifies the behavior of this operator on
#     976     Tensors that carry no data ("FakeTensor"). Given some input Tensors with
#     977     certain properties (sizes/strides/storage_offset/device), it specifies
#     978     what the properties of the output Tensors are.
#     979
#     980     The FakeTensor implementation has the same signature as the operator.
#     981     It is run for both FakeTensors and meta tensors. To write a FakeTensor
#     982     implementation, assume that all Tensor inputs to the operator are
#     983     regular CPU/CUDA/Meta tensors, but they do not have storage, and
#     984     you are trying to return regular CPU/CUDA/Meta tensor(s) as output.
#     985     The FakeTensor implementation must consist of only PyTorch operations
#     986     (and may not directly access the storage or data of any input or
#     987     intermediate Tensors).
#     988
#     989     This API may be used as a decorator (see examples).
#     990
#     991     For a detailed guide on custom ops, please see
#     992     https://pytorch.org/tutorials/advanced/custom_ops_landing_page.html
#     993
#     994     Args:
#     995         op_name: Operator name (along with the overload) or OpOverload object.
#     996         func: Fake tensor implementation.
#     997         lib (Optional[Library]): Library to register the fake tensor to.
#     998         allow_override: Flag controlling if we want to override an
#     999                         existing registered fake impl. This is by default off,
#    1000                         and will error you're trying to register a fake impl to
#    1001                         an operator that already has a fake impl. This also only
#    1002                         applies if the custom operator was not created via
#    1003                         torch.library.custom_op, as overriding and existing fake
#    1004                         impl is already allowed.
#    1005
#    1006     Examples:
#    1007         >>> import torch
#    1008         >>> import numpy as np
#    1009         >>> from torch import Tensor
#    1010         >>>
#    1011         >>> # Example 1: an operator without data-dependent output shape
#    1012         >>> @torch.library.custom_op("mylib::custom_linear", mutates_args=())
#    1013         >>> def custom_linear(x: Tensor, weight: Tensor, bias: Tensor) -> Tensor:
#    1014         >>>     raise NotImplementedError("Implementation goes here")
#    1015         >>>
#    1016         >>> @torch.library.register_fake("mylib::custom_linear")
#    1017         >>> def _(x, weight, bias):
#    1018         >>>     assert x.dim() == 2
#    1019         >>>     assert weight.dim() == 2
#    1020         >>>     assert bias.dim() == 1
#    1021         >>>     assert x.shape[1] == weight.shape[1]
#    1022         >>>     assert weight.shape[0] == bias.shape[0]
# -> 1023         >>>     assert x.device == weight.device
#    1024         >>>
#    1025         >>>     return (x @ weight.t()) + bias
#    1026         >>>
#    1027         >>> with torch._subclasses.fake_tensor.FakeTensorMode():
#    1028         >>>     x = torch.randn(2, 3)
#    1029         >>>     w = torch.randn(3, 3)
#    1030         >>>     b = torch.randn(3)
#    1031         >>>     y = torch.ops.mylib.custom_linear(x, w, b)
#    1032         >>>
#    1033         >>> assert y.shape == (2, 3)
#    1034         >>>
#    1035         >>> # Example 2: an operator with data-dependent output shape
#    1036         >>> @torch.library.custom_op("mylib::custom_nonzero", mutates_args=())
#    1037         >>> def custom_nonzero(x: Tensor) -> Tensor:
#    1038         >>>     x_np = x.numpy(force=True)
#    1039         >>>     res = np.stack(np.nonzero(x_np), axis=1)
#    1040         >>>     return torch.tensor(res, device=x.device)
#    1041         >>>
#    1042         >>> @torch.library.register_fake("mylib::custom_nonzero")
#    1043         >>> def _(x):
#    1044         >>> # Number of nonzero-elements is data-dependent.
#    1045         >>> # Since we cannot peek at the data in an fake impl,
#    1046         >>> # we use the ctx object to construct a new symint that
#    1047         >>> # represents the data-dependent size.
#    1048         >>>     ctx = torch.library.get_ctx()
#    1049         >>>     nnz = ctx.new_dynamic_size()
#    1050         >>>     shape = [nnz, x.dim()]
#    1051         >>>     result = x.new_empty(shape, dtype=torch.int64)
#    1052         >>>     return result
#    1053         >>>
#    1054         >>> from torch.fx.experimental.proxy_tensor import make_fx
#    1055         >>>
#    1056         >>> x = torch.tensor([0, 1, 2, 3, 4, 0])
#    1057         >>> trace = make_fx(torch.ops.mylib.custom_nonzero, tracing_mode="symbolic")(x)
#    1058         >>> trace.print_readable()
#    1059         >>>
#    1060         >>> assert torch.allclose(trace(x), torch.ops.mylib.custom_nonzero(x))
#    1061
#    1062     """
#    1063     if not isinstance(
#    1064         op, (str, torch._ops.OpOverload, torch._library.custom_ops.CustomOpDef)
#    1065     ):
#    1066         raise ValueError(f"register_fake({op}): got unexpected type for op: {type(op)}")
#
# File ~\anaconda3\envs\IA_Gen_env\Lib\site-packages\torch\library.py:214, in _register_fake(self, op_name, fn, _stacklevel)
#     209 def _register_torch_dispatch_rule(self, op_name, torch_dispatch_class, fn):
#     210     r"""Registers a torch_dispatch rule for the given operator and torch_dispatch_class.
#     211
#     212     This allows for open registration to specify the behavior between the operator
#     213     and the torch_dispatch_class without needing to modify the torch_dispatch_class
# --> 214     or the operator directly.
#     215
#     216     The torch_dispatch_class is either a Tensor subclass with `__torch_dispatch__` or a
#     217     TorchDispatchMode.
#     218
#     219     If it is a Tensor subclass, we expect fn to have the following signature:
#     220     (cls, func: OpOverload, types: Tuple[type, ...], args, kwargs) -> Any
#     221
#     222     If it is a TorchDispatchMode, we expect fn to have the following signature:
#     223     (mode, func: OpOverload, types: Tuple[type, ...], args, kwargs) -> Any
#     224     """
#     226     qualname = f"{self.ns}::{op_name}"
#     227     entry = torch._library.simple_registry.singleton.find(qualname)
#
# File ~\anaconda3\envs\IA_Gen_env\Lib\site-packages\torch\_library\fake_impl.py:31, in register(self, func, source)
#      27         return None
#      28     return self.kernels[-1]
#      30 @kernel.setter
# ---> 31 def kernel(self, value):
#      32     raise RuntimeError("Unable to directly set kernel.")
#      34 def register(
#      35     self, func: Callable, source: str, lib, *, allow_override=False
#      36 ) -> RegistrationHandle:
#
# RuntimeError: operator torchvision::nms does not exist
